# %% [markdown]
# ### Cleaning the US I94 ports in Non-US region
#
#
# The following cleaning process has been taken up:
#
# 1. Each entry's airport/passing, city, state or province, country is identified.
#
#     Reason: To match with the airport codes data.
#
#    For example:
#
#    'TOK'	=	'Torokina #ARPRT, New Guinea'
#
#    is changed to:
#
#    'TOK'	=	'Torokina Airport, Torokina, Bougainville, New Guinea'
#
#    'Code'	=	Airport/Crossing, City, State, Country
#
#    This matches with the muncipality 'Torokina' in the Airports code data.

# %%
import pandas as pd
import numpy as np
import us

# %%
I94_port_codes = []
I94_ac = []
I94_city = []
I94_state = []
I94_country = []

# %%
with open('../I94_Ports_Non_US.txt') as f:
    for line in f:
        temp = line.strip('\n').split("\t=\t")
        I94_port_codes.append(temp[0].strip("'"))
        exp = temp[1].strip("'").split(",")
        I94_country.append(exp[-1].strip())
        I94_state.append(exp[-2].strip())
        I94_city.append(exp[-3].strip())
        if len(exp)==4:
            I94_ac.append(exp[-4].strip())
        else:
            I94_ac.append("")
#         print(I94_port_codes)
#         print(I94_country)
#         print(I94_state)
#         print(I94_city)
#         print(I94_ac)
#         break

# %%
print(len(I94_port_codes))
print(len(I94_country))
print(len(I94_state))
print(len(I94_city))
print(len(I94_ac))
# Out:
# 57
# 57
# 57
# 57
# 57

# %%
df_I94_nonUS = pd.DataFrame({'code':I94_port_codes, 
                           'port': I94_ac, 
                           'locality': I94_city, 
                           'province': I94_state, 
                           'territory': I94_country})

# %%
df_I94_nonUS
# Out:
#    code                                          port             locality  \
# 0   CLG                                                            Calgary
# 1   EDA                                                           Edmonton
# 2   YHC                                                         Hakai pass
# 3   HAL                                                            Halifax
# 4   MON                                                           Montreal
# 5   OTT                                                             Ottawa
# 6   YXE                                                          Saskatoon
# 7   TOR                                                            Toronto
# 8   VCV                                                          Vancouver
# 9   VIC                                                           Victoria
# 10  WIN                                                           Winnipeg
# 11  AMS                    Amsterdam-Schiphol Airport            Amsterdam
# 12  ARB                                                         Oranjestad
# 13  BAN                                                            Bangkok
# 14  BEI                                 Beica Airport                Beica
# 15  PEK         Beijing Capital International Airport              Beijing
# 16  BDA                                                      Kindley Field
# 17  BOG                             El Dorado Airport               Bogota
# 18  EZE      Ministro Pistarini International Airport         Buenos Aires
# 19  CUN                                                             Cancun
# 20  CRQ                             Caravelas Airport            Caravelas
# 21  MVD                Carrasco International Airport   Ciudad de la Costa
# 22  DUB                                                             Dublin
# 23  FOU                              Fougamou Airport             Fougamou
# 24  FBA                                                           Freeport
# 25  MTY               Monterrey International Airport              Apodaca
# 26  HMO              General Pesqueira Garcia Airport           Hermosillo
# 27  GCM                                                       Grand Cayman
# 28  GDL             Guadalajara International Airport          Guadalajara
# 29  HAM                                                           Hamilton
# 30  ICN                                                            Incheon
# 31  CND                                                       Kogalniceanu
# 32  LAH                                Labuha Airport               Labuha
# 33  DUR                           Louis Botha Airport               Durban
# 34  MAL                               Mangole Airport              Mangole
# 35  MDE                                                           Medellin
# 36  MEX           Benito Juarez International Airport          Mexico City
# 37  LHR                                     Middlesex               London
# 38  NBO                                                            Nairobi
# 39  NAS                                                             Nassau
# 40  NCA                                                       North Caicos
# 41  PTY                                 Omar Torrijos          Panama City
# 42  SPV                                                           Jayapura
# 43  UIO  Quito (Mariscal Sucre) International Airport                Quito
# 44  RIT                                                               Rome
# 45  SNO                          Sakon Nakhon Airport  Mueang Sakon Nakhon
# 46  SLP         San Luis Potosi International Airport      San Luis Potosi
# 47  SAN                                                       San Salvador
# 48  SRO                           Santa Ramos Airport          Santa Ramos
# 49  GRU               Guarulhos International Airport            Guarulhos
# 50  SHA                                                            Shannon
# 51  HIL                                                           Shillavo
# 52  TOK                              Torokina Airport             Torokina
# 53  VER                                                           Veracruz
# 54  LGW                                                        West Sussex
# 55  MAA                                                          Abu Dhabi
# 56  SAI                                                             Saipan
#
#                       state                   country
# 0                   Alberta                    Canada
# 1                   Alberta                    Canada
# 2          British Columbia                    Canada
# 3               Nova Scotia                    Canada
# 4                    Quebec                    Canada
# 5                   Ontario                    Canada
# 6              Saskatchewan                    Canada
# 7                   Ontario                    Canada
# 8          British Columbia                    Canada
# 9          British Columbia                    Canada
# 10                 Manitoba                    Canada
# 11            North Holland               Netherlands
# 12                    Aruba             Neth Antilles
# 13         Central Thailand                  Thailand
# 14                   Oromia                  Ethiopia
# 15                  Beijing  Public Republic of China
# 16              Saint Davis                   Bermuda
# 17             Cundinamarca                  Colombia
# 18                 La Plata                 Argentina
# 19             Quintana Roo                    Mexico
# 20                    Bahia                    Brazil
# 21                Canelones                   Uruguay
# 22                 Leinster                   Ireland
# 23         Ngounie Province                     Gabon
# 24             Grand Bahama                   Bahamas
# 25               Nuevo Leon                    Mexico
# 26                   Sonora                    Mexico
# 27              George Town             Cayman Island
# 28                  Jalisco                    Mexico
# 29                                            Bermuda
# 30                 Gyeonggi               Seoul Korea
# 31                  Dobruja                   Romania
# 32  South Halmahera Regency                 Indonesia
# 33            KwaZulu-Natal              South Africa
# 34             Sula Islands                 Indonesia
# 35                Antioquia                  Colombia
# 36              Mexico City                    Mexico
# 37                  England            United Kingdom
# 38                  Nairobi                     Kenya
# 39                                            Bahamas
# 40                                   Turks and Caicos
# 41                   Panama                    Panama
# 42                    Papua                New Guinea
# 43                Pichincha                   Ecuador
# 44                    Lazio                     Italy
# 45             Sakon Nakhon                  Thailand
# 46          San Luis Potosi                    Mexico
# 47             San Salvador               El Salvador
# 48                  Caqueta                  Colombia
# 49                Sao Paulo                    Brazil
# 50                  Munster                   Ireland
# 51                   Somali                  Ethiopia
# 52             Bougainville                New Guinea
# 53                 Veracruz                    Mexico
# 54                  England            United Kingdom
# 55                               United Arab Emirates
# 56                           Northern Mariana Islands

# %% [markdown]
# ### Cleaning the data dictionary for the I94port Codes in US region
#
# 1. Separating out the US ports and Non-US ports.
# 2. Replacing the shortcuts like 'INTL' with International, and 'ARPRT' with Airport.
# 3. Replacing the combined airports like:
#
#         OAKLAND COUNTY - PONTIAC AIRPORT, PONTIAC, MI AS OAKLAND COUNTY - PONTIAC, MI
# 4. Handling the typos:
#
#         HAMLIN, ME as HAMIIN, ME
# 5. Adding the city name, if airport name is found in I94 port definition:
#
#         Given: BILOXI REGIONAL, MS
#         Changed to: BILOXI REGIONAL AIRPORT, BILOXI, MS
#
# 6. Identified crossings and bridges in the I94 ports.
# 7. Made sure that every I94 port has an associated city which is marked as entering city/Town. This in referred as locality in the coming sections.
# 8. Each entry's airport/passing, city, state or province is identified.
#
#     Reason: To match with the airport codes data.
#
#    For example:
#
#    'MOS'	=	'MOSES POINT INTERMEDIATE, AK'
#
#    is changed to:
#
#    'MOS'='Moses Point Intermediate Airport, MOSES POINT, AK'
#
#    'Code'	=	Airport/Crossing, City, State
#
#    This matches with the muncipality 'Moses Point' in the Airports code data.

# %%
I94_port_codesX = []
I94_acX = []
I94_cityX = []
I94_stateX = []
I94_countryX = []

# %%
with open('../I94_Ports_US.txt') as f:
    for line in f:
        temp = line.strip('\n').split("\t=\t")
        I94_port_codesX.append(temp[0].strip("'"))
        exp = temp[1].strip().strip("'").split(",")
        I94_countryX.append("Unites States")
        I94_stateX.append(us.states.lookup(exp[-1].strip()).name)
        I94_cityX.append(" ".join([elem.capitalize() for elem in exp[-2].strip().split(" ")]))
        if len(exp)==3:
            I94_acX.append(exp[-3].strip())
        else:
            I94_acX.append("")
        if len(exp)>3:
            print(line)
#         print(I94_port_codesX)
#         print(I94_countryX)
#         print(I94_stateX)
#         print(I94_cityX)
#         print(I94_acX)
#         break

# %%
df_us = pd.DataFrame({'code':I94_port_codesX, 
                           'port': I94_acX, 
                           'locality': I94_cityX, 
                           'province': I94_stateX, 
                           'territory': I94_countryX})

# %%
pd.set_option('display.max_rows', 600)
df_us.head()
# Out:
#   code           port      locality   state        country
# 0  ALC                        Alcan  Alaska  Unites States
# 1  ANC                    Anchorage  Alaska  Unites States
# 2  BAR      Baker AAF  Baker Island  Alaska  Unites States
# 3  DAC  Daltons Cache        Haines  Alaska  Unites States
# 4  PIZ    DEW Station     Point Lay  Alaska  Unites States

# %% [markdown]
# ### Finally Adding the not reported or unidentified ports
#
# 'XXX'	=	'NOT REPORTED/UNKNOWN, NOT REPORTED/UNKNOWN  '
#
# '888'	=	'UNIDENTIFED AIR / SEAPORT, UNIDENTIFED AIR / SEAPORT'
#
# 'UNK'	=	'UNKNOWN POE, UNKNOWN POE           '

# %%
I94_port_codesX += ['XXX', '888', 'UNK']
I94_acX += ['NOT REPORTED/UNKNOWN', 'UNIDENTIFED AIR / SEAPORT', 'UNKNOWN POE']
I94_cityX += ['NOT REPORTED/UNKNOWN', 'UNIDENTIFED AIR / SEAPORT', 'UNKNOWN POE']
I94_stateX += ['NOT REPORTED/UNKNOWN', 'UNIDENTIFED AIR / SEAPORT', 'UNKNOWN POE']
I94_countryX += ['NOT REPORTED/UNKNOWN', 'UNIDENTIFED AIR / SEAPORT', 'UNKNOWN POE']

# %%
df_us = pd.DataFrame({'code':I94_port_codesX, 
                           'port': I94_acX, 
                           'locality': I94_cityX, 
                           'province': I94_stateX, 
                           'terrtitory': I94_countryX})

# %%
df_us.tail()
# Out:
#     code                       port                   locality  \
# 536  GTF                                   International Falls
# 537  INL                                   International Falls
# 538  XXX       NOT REPORTED/UNKNOWN       NOT REPORTED/UNKNOWN
# 539  888  UNIDENTIFED AIR / SEAPORT  UNIDENTIFED AIR / SEAPORT
# 540  UNK                UNKNOWN POE                UNKNOWN POE
#
#                          state                    country
# 536                  Minnesota              Unites States
# 537                  Minnesota              Unites States
# 538       NOT REPORTED/UNKNOWN       NOT REPORTED/UNKNOWN
# 539  UNIDENTIFED AIR / SEAPORT  UNIDENTIFED AIR / SEAPORT
# 540                UNKNOWN POE                UNKNOWN POE

# %% [markdown]
# ### Merging the US and Non-US ports into one dataframe and Save

# %%
df_ports = pd.concat([df_I94_nonUS, df_us], ignore_index=True)

# %%
df_ports.head()
# Out:
#   code port    locality             state country
# 0  CLG          Calgary           Alberta  Canada
# 1  EDA         Edmonton           Alberta  Canada
# 2  YHC       Hakai pass  British Columbia  Canada
# 3  HAL          Halifax       Nova Scotia  Canada
# 4  MON         Montreal            Quebec  Canada

# %%
df_ports.tail()
# Out:
#     code                       port                   locality  \
# 593  GTF                                   International Falls
# 594  INL                                   International Falls
# 595  XXX       NOT REPORTED/UNKNOWN       NOT REPORTED/UNKNOWN
# 596  888  UNIDENTIFED AIR / SEAPORT  UNIDENTIFED AIR / SEAPORT
# 597  UNK                UNKNOWN POE                UNKNOWN POE
#
#                          state                    country
# 593                  Minnesota              Unites States
# 594                  Minnesota              Unites States
# 595       NOT REPORTED/UNKNOWN       NOT REPORTED/UNKNOWN
# 596  UNIDENTIFED AIR / SEAPORT  UNIDENTIFED AIR / SEAPORT
# 597                UNKNOWN POE                UNKNOWN POE

# %%
df_ports.to_csv('../Cleaned Data/I94_ports.csv', index=False)

# %%
df_ports_valid_codes = df_ports[['code']]

# %%
# df_ports_valid_codes.to_csv('../Cleaned Data/I94_ports_code.csv', index=False)
